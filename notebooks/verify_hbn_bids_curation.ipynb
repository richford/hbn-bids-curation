# %% [markdown]
# Import the required libraries

# %%
import AFQ.data as afqd
import os.path as op
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# /opt/conda/envs/hbn-bids-curation/lib/python3.8/site-packages/dask/dataframe/utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Load information on the subjects and their AWS S3 keys in the "raw" HBN datasets.
# This will take something like 16 minutes.

# %%
sites = ["Site-SI", "Site-RU", "Site-CBIC", "Site-CUNY"]
hbn_orig = {}

for site in sites:
    hbn_orig[site] = afqd.HBNSite(site, subjects="all")
# Out:
# /opt/conda/envs/hbn-bids-curation/lib/python3.8/site-packages/bids/layout/models.py:98: FutureWarning: The 'extension' entity currently excludes the leading dot ('.'). As of version 0.14.0, it will include the leading dot. To suppress this warning and include the leading dot, use `bids.config.set_option('extension_initial_dot', True)`.
#   warnings.warn("The 'extension' entity currently excludes the leading dot ('.'). "
# Retrieving subject S3 keys
# [########################################] | 100% Completed |  2min 55.8s
# Retrieving subject S3 keys
# [########################################] | 100% Completed |  8min 49.1s
# Retrieving subject S3 keys
# [########################################] | 100% Completed | 10min 27.8s
# Retrieving subject S3 keys
# [########################################] | 100% Completed | 33.2s

# %% [markdown]
# Now load the curated dataset and the qsiprep output as two separate datasets. This part will take something like 20 minutes.

# %%
curated = afqd.S3BIDSStudy(
    "hbn_curated-0",
    bucket="fcp-indi",
    s3_prefix="data/Projects/HBN/BIDS_curated",
    subjects="all",
)

qsiprepped = afqd.S3BIDSStudy(
    "hbn_curated_qsiprep-0",
    bucket="fcp-indi",
    s3_prefix="data/Projects/HBN/BIDS_curated/derivatives/qsiprep",
    # no need to use subjects="all" here since we won't need the S3 keys
)
# Out:
# Retrieving subject S3 keys
# [########################################] | 100% Completed | 22min 36.6s
# Retrieving subject S3 keys
# [########################################] | 100% Completed |  0.5s

# %% [markdown]
# Print the total number of subjects in each "raw" site and also in the curated and qsiprep datasets

# %%
for site in sites:
    print(f"{site:10s}: {len(hbn_orig[site]._all_subjects)}")
    
print(f"curated   : {len(curated._all_subjects)}")
print(f"qsiprepped: {len(qsiprepped._all_subjects)}")
# Out:
# Site-SI   : 343
# Site-RU   : 1227
# Site-CBIC : 1081
# Site-CUNY : 96
# curated   : 2615
# qsiprepped: 2136

# %% [markdown]
# So it looks like we have 2,747 subjects in the "raw" sites, 2,615 subjects in the `BIDS_curated` dataset, and 2,136 subjects that have successfully gone through qsiprep.

# %% [markdown]
# ## Build pandas dataframes
#
# Now we're going to build pandas DataFrames that contain the AWS S3 keys for each subject's imaging files. We will require only the following files:
#
# - anat
#   - T1w.nii.gz
#   - T1w.json
# - dwi
#   - dwi.nii.gz
#   - dwi.json
#   - dwi.bval
#   - dwi.bvec
#
# And we will exclude any files with "TRACEW" in the name.

# %%
def get_key(list_of_keys, modality, suffix):
    """Get an S3 for a specific imaging file
    
    Parameters
    ----------
    list_of_keys : list
        List of AWS S3 keys
        
    modality : "anat" or "dwi"
        The imaging modality
        
    suffix : str
        The image file suffix, e.g. dwi.nii.gz, dwi.bvec, or T1w.nii.gz
    
    Returns
    -------
    AWS S3 key (type str) or np.nan if the key wasn't found
    """
    if modality not in ["anat", "dwi"]:
        pass
    
    key = [
        k for k in list_of_keys
        if "/" + modality + "/" in k and k.endswith(suffix) and "TRACE" not in k
    ]
    
    if len(key):
        return key[0]
    else:
        return np.nan

def get_raw_df(site):
    """Build a pandas dataframe with AWS S3 keys for the raw dataset
    
    The dataframe will have 'participant_id' as a the index
    and columns for raw dwi and anat files.
    
    Returns
    -------
    pd.DataFrame
    """
    dicts = [
        {
            "participant_id": sub.subject_id.replace("sub-", ""),
            "raw_site": sub.site,
            "raw_dwi_nifti": get_key(sub.s3_keys["raw"], "dwi", "dwi.nii.gz"),
            "raw_dwi_json": get_key(sub.s3_keys["raw"], "dwi", "dwi.json"),
            "raw_dwi_bval": get_key(sub.s3_keys["raw"], "dwi", "dwi.bvec"),
            "raw_dwi_bvec": get_key(sub.s3_keys["raw"], "dwi", "dwi.bval"),
            "raw_t1w_nifti": get_key(sub.s3_keys["raw"], "anat", "T1w.nii.gz"),
            "raw_t1w_json": get_key(sub.s3_keys["raw"], "anat", "T1w.json"),
        } for sub in site.subjects
    ]
    
    return pd.DataFrame(dicts).set_index("participant_id", drop=True)

def get_curated_df(study):
    """Build a pandas dataframe with AWS S3 keys for the curated dataset
    
    The dataframe will have 'participant_id' as a the index
    and columns for raw dwi and anat files.
    
    Returns
    -------
    pd.DataFrame
    """
    dicts = [
        {
            "participant_id": sub.subject_id.replace("sub-", ""),
            "curated_site": sub.s3_keys["raw"][0].split(sub.subject_id)[1].replace("/ses-HBNsite", "Site-")[:7],
            "curated_dwi_nifti": get_key(sub.s3_keys["raw"], "dwi", "dwi.nii.gz"),
            "curated_dwi_json": get_key(sub.s3_keys["raw"], "dwi", "dwi.json"),
            "curated_dwi_bval": get_key(sub.s3_keys["raw"], "dwi", "dwi.bvec"),
            "curated_dwi_bvec": get_key(sub.s3_keys["raw"], "dwi", "dwi.bval"),
            "curated_t1w_nifti": get_key(sub.s3_keys["raw"], "anat", "T1w.nii.gz"),
            "curated_t1w_json": get_key(sub.s3_keys["raw"], "anat", "T1w.json"),
        } for sub in study.subjects
    ]
    
    return pd.DataFrame(dicts).set_index("participant_id", drop=True)

# %% [markdown]
# Create the "raw" dataframe

# %%
df_raw = pd.concat({
    site: get_raw_df(site_study) for site, site_study in hbn_orig.items()
}.values())
df_raw["participant_id_upper"] = [s.upper() for s in df_raw.index]
df_raw.head()
# Out:
#                raw_site                                      raw_dwi_nifti  \
# participant_id
# NDARJR525HTX    Site-SI  data/Projects/HBN/MRI/Site-SI/sub-NDARJR525HTX...
# NDARXB704HFD    Site-SI  data/Projects/HBN/MRI/Site-SI/sub-NDARXB704HFD...
# NDARMM905VYR    Site-SI  data/Projects/HBN/MRI/Site-SI/sub-NDARMM905VYR...
# NDARML148UCE    Site-SI  data/Projects/HBN/MRI/Site-SI/sub-NDARML148UCE...
# NDARED047DTH    Site-SI  data/Projects/HBN/MRI/Site-SI/sub-NDARED047DTH...
#
#                                                      raw_dwi_json  \
# participant_id
# NDARJR525HTX    data/Projects/HBN/MRI/Site-SI/sub-NDARJR525HTX...
# NDARXB704HFD    data/Projects/HBN/MRI/Site-SI/sub-NDARXB704HFD...
# NDARMM905VYR    data/Projects/HBN/MRI/Site-SI/sub-NDARMM905VYR...
# NDARML148UCE    data/Projects/HBN/MRI/Site-SI/sub-NDARML148UCE...
# NDARED047DTH    data/Projects/HBN/MRI/Site-SI/sub-NDARED047DTH...
#
#                                                      raw_dwi_bval  \
# participant_id
# NDARJR525HTX    data/Projects/HBN/MRI/Site-SI/sub-NDARJR525HTX...
# NDARXB704HFD    data/Projects/HBN/MRI/Site-SI/sub-NDARXB704HFD...
# NDARMM905VYR    data/Projects/HBN/MRI/Site-SI/sub-NDARMM905VYR...
# NDARML148UCE    data/Projects/HBN/MRI/Site-SI/sub-NDARML148UCE...
# NDARED047DTH    data/Projects/HBN/MRI/Site-SI/sub-NDARED047DTH...
#
#                                                      raw_dwi_bvec  \
# participant_id
# NDARJR525HTX    data/Projects/HBN/MRI/Site-SI/sub-NDARJR525HTX...
# NDARXB704HFD    data/Projects/HBN/MRI/Site-SI/sub-NDARXB704HFD...
# NDARMM905VYR    data/Projects/HBN/MRI/Site-SI/sub-NDARMM905VYR...
# NDARML148UCE    data/Projects/HBN/MRI/Site-SI/sub-NDARML148UCE...
# NDARED047DTH    data/Projects/HBN/MRI/Site-SI/sub-NDARED047DTH...
#
#                                                     raw_t1w_nifti  \
# participant_id
# NDARJR525HTX    data/Projects/HBN/MRI/Site-SI/sub-NDARJR525HTX...
# NDARXB704HFD    data/Projects/HBN/MRI/Site-SI/sub-NDARXB704HFD...
# NDARMM905VYR    data/Projects/HBN/MRI/Site-SI/sub-NDARMM905VYR...
# NDARML148UCE    data/Projects/HBN/MRI/Site-SI/sub-NDARML148UCE...
# NDARED047DTH    data/Projects/HBN/MRI/Site-SI/sub-NDARED047DTH...
#
#                                                      raw_t1w_json  \
# participant_id
# NDARJR525HTX    data/Projects/HBN/MRI/Site-SI/sub-NDARJR525HTX...
# NDARXB704HFD    data/Projects/HBN/MRI/Site-SI/sub-NDARXB704HFD...
# NDARMM905VYR    data/Projects/HBN/MRI/Site-SI/sub-NDARMM905VYR...
# NDARML148UCE    data/Projects/HBN/MRI/Site-SI/sub-NDARML148UCE...
# NDARED047DTH    data/Projects/HBN/MRI/Site-SI/sub-NDARED047DTH...
#
#                participant_id_upper
# participant_id
# NDARJR525HTX           NDARJR525HTX
# NDARXB704HFD           NDARXB704HFD
# NDARMM905VYR           NDARMM905VYR
# NDARML148UCE           NDARML148UCE
# NDARED047DTH           NDARED047DTH

# %% [markdown]
# Create the "curated" dataframe.

# %%
df_curated = get_curated_df(curated)
df_curated["participant_id_upper"] = [s.upper() for s in df_curated.index]
df_curated.head()
# Out:
#                curated_site  \
# participant_id
# NDARHZ413DZL        Site-CB
# NDARMN695VFH        Site-RU
# NDARYU898ETS        Site-RU
# NDARZJ016GL0        Site-RU
# NDARHN067BTE        Site-RU
#
#                                                 curated_dwi_nifti  \
# participant_id
# NDARHZ413DZL    data/Projects/HBN/BIDS_curated/sub-NDARHZ413DZ...
# NDARMN695VFH    data/Projects/HBN/BIDS_curated/sub-NDARMN695VF...
# NDARYU898ETS    data/Projects/HBN/BIDS_curated/sub-NDARYU898ET...
# NDARZJ016GL0    data/Projects/HBN/BIDS_curated/sub-NDARZJ016GL...
# NDARHN067BTE    data/Projects/HBN/BIDS_curated/sub-NDARHN067BT...
#
#                                                  curated_dwi_json  \
# participant_id
# NDARHZ413DZL    data/Projects/HBN/BIDS_curated/sub-NDARHZ413DZ...
# NDARMN695VFH    data/Projects/HBN/BIDS_curated/sub-NDARMN695VF...
# NDARYU898ETS    data/Projects/HBN/BIDS_curated/sub-NDARYU898ET...
# NDARZJ016GL0    data/Projects/HBN/BIDS_curated/sub-NDARZJ016GL...
# NDARHN067BTE    data/Projects/HBN/BIDS_curated/sub-NDARHN067BT...
#
#                                                  curated_dwi_bval  \
# participant_id
# NDARHZ413DZL    data/Projects/HBN/BIDS_curated/sub-NDARHZ413DZ...
# NDARMN695VFH    data/Projects/HBN/BIDS_curated/sub-NDARMN695VF...
# NDARYU898ETS    data/Projects/HBN/BIDS_curated/sub-NDARYU898ET...
# NDARZJ016GL0    data/Projects/HBN/BIDS_curated/sub-NDARZJ016GL...
# NDARHN067BTE    data/Projects/HBN/BIDS_curated/sub-NDARHN067BT...
#
#                                                  curated_dwi_bvec  \
# participant_id
# NDARHZ413DZL    data/Projects/HBN/BIDS_curated/sub-NDARHZ413DZ...
# NDARMN695VFH    data/Projects/HBN/BIDS_curated/sub-NDARMN695VF...
# NDARYU898ETS    data/Projects/HBN/BIDS_curated/sub-NDARYU898ET...
# NDARZJ016GL0    data/Projects/HBN/BIDS_curated/sub-NDARZJ016GL...
# NDARHN067BTE    data/Projects/HBN/BIDS_curated/sub-NDARHN067BT...
#
#                                                 curated_t1w_nifti  \
# participant_id
# NDARHZ413DZL    data/Projects/HBN/BIDS_curated/sub-NDARHZ413DZ...
# NDARMN695VFH    data/Projects/HBN/BIDS_curated/sub-NDARMN695VF...
# NDARYU898ETS    data/Projects/HBN/BIDS_curated/sub-NDARYU898ET...
# NDARZJ016GL0    data/Projects/HBN/BIDS_curated/sub-NDARZJ016GL...
# NDARHN067BTE    data/Projects/HBN/BIDS_curated/sub-NDARHN067BT...
#
#                                                  curated_t1w_json  \
# participant_id
# NDARHZ413DZL    data/Projects/HBN/BIDS_curated/sub-NDARHZ413DZ...
# NDARMN695VFH                                                  NaN
# NDARYU898ETS    data/Projects/HBN/BIDS_curated/sub-NDARYU898ET...
# NDARZJ016GL0    data/Projects/HBN/BIDS_curated/sub-NDARZJ016GL...
# NDARHN067BTE                                                  NaN
#
#                participant_id_upper
# participant_id
# NDARHZ413DZL           NDARHZ413DZL
# NDARMN695VFH           NDARMN695VFH
# NDARYU898ETS           NDARYU898ETS
# NDARZJ016GL0           NDARZJ016GL0
# NDARHN067BTE           NDARHN067BTE

# %% [markdown]
# ## Missing "raw" subjects
#
# Let's see if there are any subjects in the `BIDS_curated` dataset that are not in the "raw" site data

# %%
print(set(df_curated.index) - set(pd.unique(df_raw.index)))
# Out:
# {'NDARPU329MDJ', 'NDARUH712NRU', 'NDARDX857DLB', 'NDARHD952XHH', 'NDARCR594JN0', 'ndarvn280jtn'}

# %% [markdown]
# Oddly, there are six subjects in the curated dataset that aren't in the raw data. But one of these has a participant ID that is all lowercase. Let's check again with case insensitivity

# %%
missing_raw_subs = set(df_curated["participant_id_upper"]) - set(pd.unique(df_raw["participant_id_upper"]))
print(missing_raw_subs)
np.savetxt("missing_raw_subs.txt", np.array(list(missing_raw_subs)), fmt="%s")
# Out:
# {'NDARPU329MDJ', 'NDARUH712NRU', 'NDARDX857DLB', 'NDARHD952XHH', 'NDARCR594JN0'}

# %% [markdown]
# Okay, so we actually have two different problems here.
#
# 1. There are five subjects in the `BIDS_curated` dataset that are not in the "raw" sites. We should figure out where the raw data is and put it up on FCP-INDI.
# 1. There is one subject who is represented twice in the `BIDS_curated` dataset, once with all caps and once with lowercase letters. We should figure out which one of these two is the correct one and delete the other.

# %% [markdown]
# ## Missing curated subjects
#
# Now let's see which subjects are represented in the "raw" dataset but missing in the `BIDS_curated` dataset

# %%
missing_curated_subs = set(df_raw.index) - set(df_curated.index)
print(len(missing_curated_subs))
np.savetxt("missing_curated_subs.txt", np.array(list(missing_curated_subs)), fmt="%s")
# Out:
# 138

# %% [markdown]
# ### Missing curated subjects with DWI
#
# We're particularly interested in subjects that are missing from the curated datasets but who have the minimal set of `dwi` and `anat` files. So let's merge the two dataframes to compare subjects that are in the "raw" data but not in the curated data.

# %%
df_hbn = df_raw.merge(df_curated, how="outer", left_index=True, right_index=True, sort=True)
df_hbn["qsiprep_success"] = ["sub-" + sub in qsiprepped._all_subjects for sub in df_hbn.index]
df_hbn["curated_site"] = df_hbn["curated_site"].map({
    "Site-SI": "Site-SI",
    "Site-RU": "Site-RU",
    "Site-CB": "Site-CBIC",
    "Site-CU": "Site-CUNY",
})

# We want participants who at least have raw dwi and anat file,
# so let's drop the others from the dataframe

# Drop subjects who are missing any of the required raw files
df_hbn.dropna(subset=[
    "raw_dwi_nifti", "raw_dwi_json", "raw_dwi_bval",
    "raw_dwi_bvec", "raw_t1w_nifti", "raw_t1w_json"
], inplace=True)

# Drop the columns for upper case subject ID since we're done with those
df_hbn.drop(["participant_id_upper_x", "participant_id_upper_y"], axis="columns", inplace=True)

# Create a new binary column for whether of not the subject is in the curated dataset
df_hbn["in_bids_curated"] = ["sub-" + sub in curated._all_subjects for sub in df_hbn.index]

# Create a new dataframe for subjects that have the required raw
# files but are missing from the curated dataset
not_curated_with_raw_files = df_hbn[df_hbn["in_bids_curated"] == False]

print(len(not_curated_with_raw_files))
np.savetxt(
    "missing_curated_subs_that_have_raw_dwi.txt",
    np.array(not_curated_with_raw_files.index),
    fmt="%s"
)
# Out:
# 106

# %% [markdown]
# So there are 106 subjects that have the minimal dwi and anat files in the raw dataset but are missing from the curated dataset.

# %% [markdown]
# ## Curated subjects that failed qsiprep
#
# Lastly, let's get a list of subjects that are in the curated dataset but who did not successfully finish preprocessing with QSIprep.

# %%
in_curated = df_hbn[df_hbn["in_bids_curated"] == True]
no_qsiprep = in_curated[in_curated["qsiprep_success"] == False]
print(len(no_qsiprep))
np.savetxt(
    "failed_qsiprep_subs.txt",
    np.array(no_qsiprep.index),
    fmt="%s"
)
# Out:
# 55

# %% [markdown]
# So there are 55 subjects that failed QSIprep. We saved their subject IDs to a text file. Now let's actually look at the dataframe.

# %%
no_qsiprep
# Out:
#                  raw_site                                      raw_dwi_nifti  \
# participant_id
# NDARAA504CRN    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARAA504C...
# NDARAB756JDJ    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARAB756J...
# NDARAH976BND    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARAH976B...
# NDARAJ977PRJ    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARAJ977P...
# NDARBM490LK7      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARBM490LK7...
# NDARBN365EV3    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDARBR128UFP    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARBR128U...
# NDAREC078VFT      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDAREC078VFT...
# NDAREJ327AH7    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFE372VHL    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARFE372V...
# NDARFG568PXZ      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARFG568PXZ...
# NDARFV780ABD      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH425GB9    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARGH425G...
# NDARGH790CEF      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGK253TTG      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGK253TTG...
# NDARGX443CEU      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARHN078CDT    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN078C...
# NDARHN482HPM    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN482H...
# NDARHP395DGY    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARHP395D...
# NDARHV358ZCU    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARHV358Z...
# NDARJJ173BRX    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARJJ173B...
# NDARJZ167VEZ    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARJZ167V...
# NDARKC993YWF    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARKC993Y...
# NDARKN509RP9      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARLB671TLU      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARLB671TLU...
# NDARLY872ZXA      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARLY872ZXA...
# NDARMD666RYJ    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARMD666R...
# NDARMH249AWF      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARNA421FL7    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARNA421F...
# NDARNN042YCH    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARNN042Y...
# NDARPY302MV9    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARPY302M...
# NDARRB561VCP    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARRB561V...
# NDARRC016UZE      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARRK038CBD    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARRK038C...
# NDARRU499DP2      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARRU499DP2...
# NDARTC795CR3    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARTC795C...
# NDARTR464DCR    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARTR464D...
# NDARUP132ADW    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP132A...
# NDARUP441BKK    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP441B...
# NDARUT651WFC    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARUT651W...
# NDARVF786FUU    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARVF786F...
# NDARVP285RXV      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARVP285RXV...
# NDARWE130JMG      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARWE130JMG...
# NDARWK051GG4      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARWK051GG4...
# NDARXE854EDK    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARXE854E...
# NDARXL801JVG    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARXL801J...
# NDARXV294YRJ    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYE576WR6    Site-CUNY  data/Projects/HBN/MRI/Site-CUNY/sub-NDARYE576W...
# NDARYF272EDC    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARYF272E...
# NDARYL090TGH    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARYL090T...
# NDARYX806FL1      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
# NDARYZ906UHJ      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARYZ906UHJ...
#
#                                                      raw_dwi_json  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAA504C...
# NDARAB756JDJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAB756J...
# NDARAH976BND    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAH976B...
# NDARAJ977PRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAJ977P...
# NDARBM490LK7    data/Projects/HBN/MRI/Site-RU/sub-NDARBM490LK7...
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDARBR128UFP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBR128U...
# NDAREC078VFT    data/Projects/HBN/MRI/Site-RU/sub-NDAREC078VFT...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFE372VHL    data/Projects/HBN/MRI/Site-CBIC/sub-NDARFE372V...
# NDARFG568PXZ    data/Projects/HBN/MRI/Site-RU/sub-NDARFG568PXZ...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH425GB9    data/Projects/HBN/MRI/Site-CBIC/sub-NDARGH425G...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGK253TTG    data/Projects/HBN/MRI/Site-RU/sub-NDARGK253TTG...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARHN078CDT    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN078C...
# NDARHN482HPM    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN482H...
# NDARHP395DGY    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHP395D...
# NDARHV358ZCU    data/Projects/HBN/MRI/Site-CUNY/sub-NDARHV358Z...
# NDARJJ173BRX    data/Projects/HBN/MRI/Site-CUNY/sub-NDARJJ173B...
# NDARJZ167VEZ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARJZ167V...
# NDARKC993YWF    data/Projects/HBN/MRI/Site-CBIC/sub-NDARKC993Y...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARLB671TLU    data/Projects/HBN/MRI/Site-RU/sub-NDARLB671TLU...
# NDARLY872ZXA    data/Projects/HBN/MRI/Site-RU/sub-NDARLY872ZXA...
# NDARMD666RYJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMD666R...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARNA421FL7    data/Projects/HBN/MRI/Site-CBIC/sub-NDARNA421F...
# NDARNN042YCH    data/Projects/HBN/MRI/Site-CUNY/sub-NDARNN042Y...
# NDARPY302MV9    data/Projects/HBN/MRI/Site-CUNY/sub-NDARPY302M...
# NDARRB561VCP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRB561V...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARRK038CBD    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRK038C...
# NDARRU499DP2    data/Projects/HBN/MRI/Site-RU/sub-NDARRU499DP2...
# NDARTC795CR3    data/Projects/HBN/MRI/Site-CUNY/sub-NDARTC795C...
# NDARTR464DCR    data/Projects/HBN/MRI/Site-CBIC/sub-NDARTR464D...
# NDARUP132ADW    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP132A...
# NDARUP441BKK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP441B...
# NDARUT651WFC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUT651W...
# NDARVF786FUU    data/Projects/HBN/MRI/Site-CBIC/sub-NDARVF786F...
# NDARVP285RXV    data/Projects/HBN/MRI/Site-RU/sub-NDARVP285RXV...
# NDARWE130JMG    data/Projects/HBN/MRI/Site-RU/sub-NDARWE130JMG...
# NDARWK051GG4    data/Projects/HBN/MRI/Site-RU/sub-NDARWK051GG4...
# NDARXE854EDK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXE854E...
# NDARXL801JVG    data/Projects/HBN/MRI/Site-CUNY/sub-NDARXL801J...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYE576WR6    data/Projects/HBN/MRI/Site-CUNY/sub-NDARYE576W...
# NDARYF272EDC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYF272E...
# NDARYL090TGH    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYL090T...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
# NDARYZ906UHJ    data/Projects/HBN/MRI/Site-RU/sub-NDARYZ906UHJ...
#
#                                                      raw_dwi_bval  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAA504C...
# NDARAB756JDJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAB756J...
# NDARAH976BND    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAH976B...
# NDARAJ977PRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAJ977P...
# NDARBM490LK7    data/Projects/HBN/MRI/Site-RU/sub-NDARBM490LK7...
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDARBR128UFP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBR128U...
# NDAREC078VFT    data/Projects/HBN/MRI/Site-RU/sub-NDAREC078VFT...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFE372VHL    data/Projects/HBN/MRI/Site-CBIC/sub-NDARFE372V...
# NDARFG568PXZ    data/Projects/HBN/MRI/Site-RU/sub-NDARFG568PXZ...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH425GB9    data/Projects/HBN/MRI/Site-CBIC/sub-NDARGH425G...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGK253TTG    data/Projects/HBN/MRI/Site-RU/sub-NDARGK253TTG...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARHN078CDT    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN078C...
# NDARHN482HPM    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN482H...
# NDARHP395DGY    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHP395D...
# NDARHV358ZCU    data/Projects/HBN/MRI/Site-CUNY/sub-NDARHV358Z...
# NDARJJ173BRX    data/Projects/HBN/MRI/Site-CUNY/sub-NDARJJ173B...
# NDARJZ167VEZ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARJZ167V...
# NDARKC993YWF    data/Projects/HBN/MRI/Site-CBIC/sub-NDARKC993Y...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARLB671TLU    data/Projects/HBN/MRI/Site-RU/sub-NDARLB671TLU...
# NDARLY872ZXA    data/Projects/HBN/MRI/Site-RU/sub-NDARLY872ZXA...
# NDARMD666RYJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMD666R...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARNA421FL7    data/Projects/HBN/MRI/Site-CBIC/sub-NDARNA421F...
# NDARNN042YCH    data/Projects/HBN/MRI/Site-CUNY/sub-NDARNN042Y...
# NDARPY302MV9    data/Projects/HBN/MRI/Site-CUNY/sub-NDARPY302M...
# NDARRB561VCP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRB561V...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARRK038CBD    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRK038C...
# NDARRU499DP2    data/Projects/HBN/MRI/Site-RU/sub-NDARRU499DP2...
# NDARTC795CR3    data/Projects/HBN/MRI/Site-CUNY/sub-NDARTC795C...
# NDARTR464DCR    data/Projects/HBN/MRI/Site-CBIC/sub-NDARTR464D...
# NDARUP132ADW    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP132A...
# NDARUP441BKK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP441B...
# NDARUT651WFC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUT651W...
# NDARVF786FUU    data/Projects/HBN/MRI/Site-CBIC/sub-NDARVF786F...
# NDARVP285RXV    data/Projects/HBN/MRI/Site-RU/sub-NDARVP285RXV...
# NDARWE130JMG    data/Projects/HBN/MRI/Site-RU/sub-NDARWE130JMG...
# NDARWK051GG4    data/Projects/HBN/MRI/Site-RU/sub-NDARWK051GG4...
# NDARXE854EDK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXE854E...
# NDARXL801JVG    data/Projects/HBN/MRI/Site-CUNY/sub-NDARXL801J...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYE576WR6    data/Projects/HBN/MRI/Site-CUNY/sub-NDARYE576W...
# NDARYF272EDC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYF272E...
# NDARYL090TGH    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYL090T...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
# NDARYZ906UHJ    data/Projects/HBN/MRI/Site-RU/sub-NDARYZ906UHJ...
#
#                                                      raw_dwi_bvec  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAA504C...
# NDARAB756JDJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAB756J...
# NDARAH976BND    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAH976B...
# NDARAJ977PRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAJ977P...
# NDARBM490LK7    data/Projects/HBN/MRI/Site-RU/sub-NDARBM490LK7...
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDARBR128UFP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBR128U...
# NDAREC078VFT    data/Projects/HBN/MRI/Site-RU/sub-NDAREC078VFT...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFE372VHL    data/Projects/HBN/MRI/Site-CBIC/sub-NDARFE372V...
# NDARFG568PXZ    data/Projects/HBN/MRI/Site-RU/sub-NDARFG568PXZ...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH425GB9    data/Projects/HBN/MRI/Site-CBIC/sub-NDARGH425G...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGK253TTG    data/Projects/HBN/MRI/Site-RU/sub-NDARGK253TTG...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARHN078CDT    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN078C...
# NDARHN482HPM    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN482H...
# NDARHP395DGY    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHP395D...
# NDARHV358ZCU    data/Projects/HBN/MRI/Site-CUNY/sub-NDARHV358Z...
# NDARJJ173BRX    data/Projects/HBN/MRI/Site-CUNY/sub-NDARJJ173B...
# NDARJZ167VEZ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARJZ167V...
# NDARKC993YWF    data/Projects/HBN/MRI/Site-CBIC/sub-NDARKC993Y...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARLB671TLU    data/Projects/HBN/MRI/Site-RU/sub-NDARLB671TLU...
# NDARLY872ZXA    data/Projects/HBN/MRI/Site-RU/sub-NDARLY872ZXA...
# NDARMD666RYJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMD666R...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARNA421FL7    data/Projects/HBN/MRI/Site-CBIC/sub-NDARNA421F...
# NDARNN042YCH    data/Projects/HBN/MRI/Site-CUNY/sub-NDARNN042Y...
# NDARPY302MV9    data/Projects/HBN/MRI/Site-CUNY/sub-NDARPY302M...
# NDARRB561VCP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRB561V...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARRK038CBD    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRK038C...
# NDARRU499DP2    data/Projects/HBN/MRI/Site-RU/sub-NDARRU499DP2...
# NDARTC795CR3    data/Projects/HBN/MRI/Site-CUNY/sub-NDARTC795C...
# NDARTR464DCR    data/Projects/HBN/MRI/Site-CBIC/sub-NDARTR464D...
# NDARUP132ADW    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP132A...
# NDARUP441BKK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP441B...
# NDARUT651WFC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUT651W...
# NDARVF786FUU    data/Projects/HBN/MRI/Site-CBIC/sub-NDARVF786F...
# NDARVP285RXV    data/Projects/HBN/MRI/Site-RU/sub-NDARVP285RXV...
# NDARWE130JMG    data/Projects/HBN/MRI/Site-RU/sub-NDARWE130JMG...
# NDARWK051GG4    data/Projects/HBN/MRI/Site-RU/sub-NDARWK051GG4...
# NDARXE854EDK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXE854E...
# NDARXL801JVG    data/Projects/HBN/MRI/Site-CUNY/sub-NDARXL801J...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYE576WR6    data/Projects/HBN/MRI/Site-CUNY/sub-NDARYE576W...
# NDARYF272EDC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYF272E...
# NDARYL090TGH    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYL090T...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
# NDARYZ906UHJ    data/Projects/HBN/MRI/Site-RU/sub-NDARYZ906UHJ...
#
#                                                     raw_t1w_nifti  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAA504C...
# NDARAB756JDJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAB756J...
# NDARAH976BND    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAH976B...
# NDARAJ977PRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAJ977P...
# NDARBM490LK7    data/Projects/HBN/MRI/Site-RU/sub-NDARBM490LK7...
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDARBR128UFP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBR128U...
# NDAREC078VFT    data/Projects/HBN/MRI/Site-RU/sub-NDAREC078VFT...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFE372VHL    data/Projects/HBN/MRI/Site-CBIC/sub-NDARFE372V...
# NDARFG568PXZ    data/Projects/HBN/MRI/Site-RU/sub-NDARFG568PXZ...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH425GB9    data/Projects/HBN/MRI/Site-CBIC/sub-NDARGH425G...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGK253TTG    data/Projects/HBN/MRI/Site-RU/sub-NDARGK253TTG...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARHN078CDT    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN078C...
# NDARHN482HPM    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN482H...
# NDARHP395DGY    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHP395D...
# NDARHV358ZCU    data/Projects/HBN/MRI/Site-CUNY/sub-NDARHV358Z...
# NDARJJ173BRX    data/Projects/HBN/MRI/Site-CUNY/sub-NDARJJ173B...
# NDARJZ167VEZ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARJZ167V...
# NDARKC993YWF    data/Projects/HBN/MRI/Site-CBIC/sub-NDARKC993Y...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARLB671TLU    data/Projects/HBN/MRI/Site-RU/sub-NDARLB671TLU...
# NDARLY872ZXA    data/Projects/HBN/MRI/Site-RU/sub-NDARLY872ZXA...
# NDARMD666RYJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMD666R...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARNA421FL7    data/Projects/HBN/MRI/Site-CBIC/sub-NDARNA421F...
# NDARNN042YCH    data/Projects/HBN/MRI/Site-CUNY/sub-NDARNN042Y...
# NDARPY302MV9    data/Projects/HBN/MRI/Site-CUNY/sub-NDARPY302M...
# NDARRB561VCP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRB561V...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARRK038CBD    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRK038C...
# NDARRU499DP2    data/Projects/HBN/MRI/Site-RU/sub-NDARRU499DP2...
# NDARTC795CR3    data/Projects/HBN/MRI/Site-CUNY/sub-NDARTC795C...
# NDARTR464DCR    data/Projects/HBN/MRI/Site-CBIC/sub-NDARTR464D...
# NDARUP132ADW    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP132A...
# NDARUP441BKK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP441B...
# NDARUT651WFC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUT651W...
# NDARVF786FUU    data/Projects/HBN/MRI/Site-CBIC/sub-NDARVF786F...
# NDARVP285RXV    data/Projects/HBN/MRI/Site-RU/sub-NDARVP285RXV...
# NDARWE130JMG    data/Projects/HBN/MRI/Site-RU/sub-NDARWE130JMG...
# NDARWK051GG4    data/Projects/HBN/MRI/Site-RU/sub-NDARWK051GG4...
# NDARXE854EDK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXE854E...
# NDARXL801JVG    data/Projects/HBN/MRI/Site-CUNY/sub-NDARXL801J...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYE576WR6    data/Projects/HBN/MRI/Site-CUNY/sub-NDARYE576W...
# NDARYF272EDC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYF272E...
# NDARYL090TGH    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYL090T...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
# NDARYZ906UHJ    data/Projects/HBN/MRI/Site-RU/sub-NDARYZ906UHJ...
#
#                                                      raw_t1w_json  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAA504C...
# NDARAB756JDJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAB756J...
# NDARAH976BND    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAH976B...
# NDARAJ977PRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARAJ977P...
# NDARBM490LK7    data/Projects/HBN/MRI/Site-RU/sub-NDARBM490LK7...
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDARBR128UFP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBR128U...
# NDAREC078VFT    data/Projects/HBN/MRI/Site-RU/sub-NDAREC078VFT...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFE372VHL    data/Projects/HBN/MRI/Site-CBIC/sub-NDARFE372V...
# NDARFG568PXZ    data/Projects/HBN/MRI/Site-RU/sub-NDARFG568PXZ...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH425GB9    data/Projects/HBN/MRI/Site-CBIC/sub-NDARGH425G...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGK253TTG    data/Projects/HBN/MRI/Site-RU/sub-NDARGK253TTG...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARHN078CDT    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN078C...
# NDARHN482HPM    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHN482H...
# NDARHP395DGY    data/Projects/HBN/MRI/Site-CBIC/sub-NDARHP395D...
# NDARHV358ZCU    data/Projects/HBN/MRI/Site-CUNY/sub-NDARHV358Z...
# NDARJJ173BRX    data/Projects/HBN/MRI/Site-CUNY/sub-NDARJJ173B...
# NDARJZ167VEZ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARJZ167V...
# NDARKC993YWF    data/Projects/HBN/MRI/Site-CBIC/sub-NDARKC993Y...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARLB671TLU    data/Projects/HBN/MRI/Site-RU/sub-NDARLB671TLU...
# NDARLY872ZXA    data/Projects/HBN/MRI/Site-RU/sub-NDARLY872ZXA...
# NDARMD666RYJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMD666R...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARNA421FL7    data/Projects/HBN/MRI/Site-CBIC/sub-NDARNA421F...
# NDARNN042YCH    data/Projects/HBN/MRI/Site-CUNY/sub-NDARNN042Y...
# NDARPY302MV9    data/Projects/HBN/MRI/Site-CUNY/sub-NDARPY302M...
# NDARRB561VCP    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRB561V...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARRK038CBD    data/Projects/HBN/MRI/Site-CBIC/sub-NDARRK038C...
# NDARRU499DP2    data/Projects/HBN/MRI/Site-RU/sub-NDARRU499DP2...
# NDARTC795CR3    data/Projects/HBN/MRI/Site-CUNY/sub-NDARTC795C...
# NDARTR464DCR    data/Projects/HBN/MRI/Site-CBIC/sub-NDARTR464D...
# NDARUP132ADW    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP132A...
# NDARUP441BKK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUP441B...
# NDARUT651WFC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARUT651W...
# NDARVF786FUU    data/Projects/HBN/MRI/Site-CBIC/sub-NDARVF786F...
# NDARVP285RXV    data/Projects/HBN/MRI/Site-RU/sub-NDARVP285RXV...
# NDARWE130JMG    data/Projects/HBN/MRI/Site-RU/sub-NDARWE130JMG...
# NDARWK051GG4    data/Projects/HBN/MRI/Site-RU/sub-NDARWK051GG4...
# NDARXE854EDK    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXE854E...
# NDARXL801JVG    data/Projects/HBN/MRI/Site-CUNY/sub-NDARXL801J...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYE576WR6    data/Projects/HBN/MRI/Site-CUNY/sub-NDARYE576W...
# NDARYF272EDC    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYF272E...
# NDARYL090TGH    data/Projects/HBN/MRI/Site-CBIC/sub-NDARYL090T...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
# NDARYZ906UHJ    data/Projects/HBN/MRI/Site-RU/sub-NDARYZ906UHJ...
#
#                curated_site  \
# participant_id
# NDARAA504CRN      Site-CBIC
# NDARAB756JDJ      Site-CBIC
# NDARAH976BND      Site-CBIC
# NDARAJ977PRJ      Site-CBIC
# NDARBM490LK7        Site-RU
# NDARBN365EV3      Site-CBIC
# NDARBR128UFP      Site-CBIC
# NDAREC078VFT        Site-RU
# NDAREJ327AH7      Site-CBIC
# NDARFE372VHL      Site-CBIC
# NDARFG568PXZ        Site-RU
# NDARFV780ABD        Site-RU
# NDARGF367KVL        Site-RU
# NDARGH425GB9      Site-CBIC
# NDARGH790CEF        Site-RU
# NDARGK253TTG        Site-RU
# NDARGX443CEU        Site-RU
# NDARHN078CDT      Site-CBIC
# NDARHN482HPM      Site-CBIC
# NDARHP395DGY      Site-CBIC
# NDARHV358ZCU      Site-CUNY
# NDARJJ173BRX      Site-CUNY
# NDARJZ167VEZ      Site-CBIC
# NDARKC993YWF      Site-CBIC
# NDARKN509RP9        Site-RU
# NDARLB671TLU        Site-RU
# NDARLY872ZXA        Site-RU
# NDARMD666RYJ      Site-CBIC
# NDARMH249AWF        Site-RU
# NDARMT461DNB      Site-CBIC
# NDARMU589LP6        Site-RU
# NDARNA421FL7      Site-CBIC
# NDARNN042YCH      Site-CUNY
# NDARPY302MV9      Site-CUNY
# NDARRB561VCP      Site-CBIC
# NDARRC016UZE        Site-RU
# NDARRK038CBD      Site-CBIC
# NDARRU499DP2        Site-RU
# NDARTC795CR3      Site-CUNY
# NDARTR464DCR      Site-CBIC
# NDARUP132ADW      Site-CBIC
# NDARUP441BKK      Site-CBIC
# NDARUT651WFC      Site-CBIC
# NDARVF786FUU      Site-CBIC
# NDARVP285RXV        Site-RU
# NDARWE130JMG        Site-RU
# NDARWK051GG4        Site-RU
# NDARXE854EDK      Site-CBIC
# NDARXL801JVG      Site-CUNY
# NDARXV294YRJ      Site-CBIC
# NDARYE576WR6      Site-CUNY
# NDARYF272EDC      Site-CBIC
# NDARYL090TGH      Site-CBIC
# NDARYX806FL1        Site-RU
# NDARYZ906UHJ        Site-RU
#
#                                                 curated_dwi_nifti  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/BIDS_curated/sub-NDARAA504CR...
# NDARAB756JDJ    data/Projects/HBN/BIDS_curated/sub-NDARAB756JD...
# NDARAH976BND    data/Projects/HBN/BIDS_curated/sub-NDARAH976BN...
# NDARAJ977PRJ    data/Projects/HBN/BIDS_curated/sub-NDARAJ977PR...
# NDARBM490LK7    data/Projects/HBN/BIDS_curated/sub-NDARBM490LK...
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDARBR128UFP    data/Projects/HBN/BIDS_curated/sub-NDARBR128UF...
# NDAREC078VFT    data/Projects/HBN/BIDS_curated/sub-NDAREC078VF...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFE372VHL    data/Projects/HBN/BIDS_curated/sub-NDARFE372VH...
# NDARFG568PXZ    data/Projects/HBN/BIDS_curated/sub-NDARFG568PX...
# NDARFV780ABD                                                  NaN
# NDARGF367KVL                                                  NaN
# NDARGH425GB9    data/Projects/HBN/BIDS_curated/sub-NDARGH425GB...
# NDARGH790CEF                                                  NaN
# NDARGK253TTG    data/Projects/HBN/BIDS_curated/sub-NDARGK253TT...
# NDARGX443CEU                                                  NaN
# NDARHN078CDT    data/Projects/HBN/BIDS_curated/sub-NDARHN078CD...
# NDARHN482HPM    data/Projects/HBN/BIDS_curated/sub-NDARHN482HP...
# NDARHP395DGY    data/Projects/HBN/BIDS_curated/sub-NDARHP395DG...
# NDARHV358ZCU    data/Projects/HBN/BIDS_curated/sub-NDARHV358ZC...
# NDARJJ173BRX    data/Projects/HBN/BIDS_curated/sub-NDARJJ173BR...
# NDARJZ167VEZ    data/Projects/HBN/BIDS_curated/sub-NDARJZ167VE...
# NDARKC993YWF    data/Projects/HBN/BIDS_curated/sub-NDARKC993YW...
# NDARKN509RP9                                                  NaN
# NDARLB671TLU    data/Projects/HBN/BIDS_curated/sub-NDARLB671TL...
# NDARLY872ZXA    data/Projects/HBN/BIDS_curated/sub-NDARLY872ZX...
# NDARMD666RYJ    data/Projects/HBN/BIDS_curated/sub-NDARMD666RY...
# NDARMH249AWF                                                  NaN
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARNA421FL7    data/Projects/HBN/BIDS_curated/sub-NDARNA421FL...
# NDARNN042YCH    data/Projects/HBN/BIDS_curated/sub-NDARNN042YC...
# NDARPY302MV9    data/Projects/HBN/BIDS_curated/sub-NDARPY302MV...
# NDARRB561VCP    data/Projects/HBN/BIDS_curated/sub-NDARRB561VC...
# NDARRC016UZE                                                  NaN
# NDARRK038CBD    data/Projects/HBN/BIDS_curated/sub-NDARRK038CB...
# NDARRU499DP2    data/Projects/HBN/BIDS_curated/sub-NDARRU499DP...
# NDARTC795CR3    data/Projects/HBN/BIDS_curated/sub-NDARTC795CR...
# NDARTR464DCR    data/Projects/HBN/BIDS_curated/sub-NDARTR464DC...
# NDARUP132ADW    data/Projects/HBN/BIDS_curated/sub-NDARUP132AD...
# NDARUP441BKK    data/Projects/HBN/BIDS_curated/sub-NDARUP441BK...
# NDARUT651WFC    data/Projects/HBN/BIDS_curated/sub-NDARUT651WF...
# NDARVF786FUU    data/Projects/HBN/BIDS_curated/sub-NDARVF786FU...
# NDARVP285RXV    data/Projects/HBN/BIDS_curated/sub-NDARVP285RX...
# NDARWE130JMG    data/Projects/HBN/BIDS_curated/sub-NDARWE130JM...
# NDARWK051GG4    data/Projects/HBN/BIDS_curated/sub-NDARWK051GG...
# NDARXE854EDK    data/Projects/HBN/BIDS_curated/sub-NDARXE854ED...
# NDARXL801JVG    data/Projects/HBN/BIDS_curated/sub-NDARXL801JV...
# NDARXV294YRJ                                                  NaN
# NDARYE576WR6    data/Projects/HBN/BIDS_curated/sub-NDARYE576WR...
# NDARYF272EDC    data/Projects/HBN/BIDS_curated/sub-NDARYF272ED...
# NDARYL090TGH    data/Projects/HBN/BIDS_curated/sub-NDARYL090TG...
# NDARYX806FL1                                                  NaN
# NDARYZ906UHJ    data/Projects/HBN/BIDS_curated/sub-NDARYZ906UH...
#
#                                                  curated_dwi_json  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/BIDS_curated/sub-NDARAA504CR...
# NDARAB756JDJ    data/Projects/HBN/BIDS_curated/sub-NDARAB756JD...
# NDARAH976BND    data/Projects/HBN/BIDS_curated/sub-NDARAH976BN...
# NDARAJ977PRJ    data/Projects/HBN/BIDS_curated/sub-NDARAJ977PR...
# NDARBM490LK7    data/Projects/HBN/BIDS_curated/sub-NDARBM490LK...
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDARBR128UFP    data/Projects/HBN/BIDS_curated/sub-NDARBR128UF...
# NDAREC078VFT    data/Projects/HBN/BIDS_curated/sub-NDAREC078VF...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFE372VHL    data/Projects/HBN/BIDS_curated/sub-NDARFE372VH...
# NDARFG568PXZ    data/Projects/HBN/BIDS_curated/sub-NDARFG568PX...
# NDARFV780ABD                                                  NaN
# NDARGF367KVL                                                  NaN
# NDARGH425GB9    data/Projects/HBN/BIDS_curated/sub-NDARGH425GB...
# NDARGH790CEF                                                  NaN
# NDARGK253TTG    data/Projects/HBN/BIDS_curated/sub-NDARGK253TT...
# NDARGX443CEU                                                  NaN
# NDARHN078CDT    data/Projects/HBN/BIDS_curated/sub-NDARHN078CD...
# NDARHN482HPM    data/Projects/HBN/BIDS_curated/sub-NDARHN482HP...
# NDARHP395DGY    data/Projects/HBN/BIDS_curated/sub-NDARHP395DG...
# NDARHV358ZCU    data/Projects/HBN/BIDS_curated/sub-NDARHV358ZC...
# NDARJJ173BRX    data/Projects/HBN/BIDS_curated/sub-NDARJJ173BR...
# NDARJZ167VEZ    data/Projects/HBN/BIDS_curated/sub-NDARJZ167VE...
# NDARKC993YWF    data/Projects/HBN/BIDS_curated/sub-NDARKC993YW...
# NDARKN509RP9                                                  NaN
# NDARLB671TLU    data/Projects/HBN/BIDS_curated/sub-NDARLB671TL...
# NDARLY872ZXA    data/Projects/HBN/BIDS_curated/sub-NDARLY872ZX...
# NDARMD666RYJ    data/Projects/HBN/BIDS_curated/sub-NDARMD666RY...
# NDARMH249AWF                                                  NaN
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARNA421FL7    data/Projects/HBN/BIDS_curated/sub-NDARNA421FL...
# NDARNN042YCH    data/Projects/HBN/BIDS_curated/sub-NDARNN042YC...
# NDARPY302MV9    data/Projects/HBN/BIDS_curated/sub-NDARPY302MV...
# NDARRB561VCP    data/Projects/HBN/BIDS_curated/sub-NDARRB561VC...
# NDARRC016UZE                                                  NaN
# NDARRK038CBD    data/Projects/HBN/BIDS_curated/sub-NDARRK038CB...
# NDARRU499DP2    data/Projects/HBN/BIDS_curated/sub-NDARRU499DP...
# NDARTC795CR3    data/Projects/HBN/BIDS_curated/sub-NDARTC795CR...
# NDARTR464DCR    data/Projects/HBN/BIDS_curated/sub-NDARTR464DC...
# NDARUP132ADW    data/Projects/HBN/BIDS_curated/sub-NDARUP132AD...
# NDARUP441BKK    data/Projects/HBN/BIDS_curated/sub-NDARUP441BK...
# NDARUT651WFC    data/Projects/HBN/BIDS_curated/sub-NDARUT651WF...
# NDARVF786FUU    data/Projects/HBN/BIDS_curated/sub-NDARVF786FU...
# NDARVP285RXV    data/Projects/HBN/BIDS_curated/sub-NDARVP285RX...
# NDARWE130JMG    data/Projects/HBN/BIDS_curated/sub-NDARWE130JM...
# NDARWK051GG4    data/Projects/HBN/BIDS_curated/sub-NDARWK051GG...
# NDARXE854EDK    data/Projects/HBN/BIDS_curated/sub-NDARXE854ED...
# NDARXL801JVG    data/Projects/HBN/BIDS_curated/sub-NDARXL801JV...
# NDARXV294YRJ                                                  NaN
# NDARYE576WR6    data/Projects/HBN/BIDS_curated/sub-NDARYE576WR...
# NDARYF272EDC    data/Projects/HBN/BIDS_curated/sub-NDARYF272ED...
# NDARYL090TGH    data/Projects/HBN/BIDS_curated/sub-NDARYL090TG...
# NDARYX806FL1                                                  NaN
# NDARYZ906UHJ    data/Projects/HBN/BIDS_curated/sub-NDARYZ906UH...
#
#                                                  curated_dwi_bval  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/BIDS_curated/sub-NDARAA504CR...
# NDARAB756JDJ    data/Projects/HBN/BIDS_curated/sub-NDARAB756JD...
# NDARAH976BND    data/Projects/HBN/BIDS_curated/sub-NDARAH976BN...
# NDARAJ977PRJ    data/Projects/HBN/BIDS_curated/sub-NDARAJ977PR...
# NDARBM490LK7    data/Projects/HBN/BIDS_curated/sub-NDARBM490LK...
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDARBR128UFP    data/Projects/HBN/BIDS_curated/sub-NDARBR128UF...
# NDAREC078VFT    data/Projects/HBN/BIDS_curated/sub-NDAREC078VF...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFE372VHL    data/Projects/HBN/BIDS_curated/sub-NDARFE372VH...
# NDARFG568PXZ    data/Projects/HBN/BIDS_curated/sub-NDARFG568PX...
# NDARFV780ABD    data/Projects/HBN/BIDS_curated/sub-NDARFV780AB...
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH425GB9    data/Projects/HBN/BIDS_curated/sub-NDARGH425GB...
# NDARGH790CEF    data/Projects/HBN/BIDS_curated/sub-NDARGH790CE...
# NDARGK253TTG    data/Projects/HBN/BIDS_curated/sub-NDARGK253TT...
# NDARGX443CEU    data/Projects/HBN/BIDS_curated/sub-NDARGX443CE...
# NDARHN078CDT    data/Projects/HBN/BIDS_curated/sub-NDARHN078CD...
# NDARHN482HPM    data/Projects/HBN/BIDS_curated/sub-NDARHN482HP...
# NDARHP395DGY    data/Projects/HBN/BIDS_curated/sub-NDARHP395DG...
# NDARHV358ZCU    data/Projects/HBN/BIDS_curated/sub-NDARHV358ZC...
# NDARJJ173BRX    data/Projects/HBN/BIDS_curated/sub-NDARJJ173BR...
# NDARJZ167VEZ    data/Projects/HBN/BIDS_curated/sub-NDARJZ167VE...
# NDARKC993YWF    data/Projects/HBN/BIDS_curated/sub-NDARKC993YW...
# NDARKN509RP9    data/Projects/HBN/BIDS_curated/sub-NDARKN509RP...
# NDARLB671TLU    data/Projects/HBN/BIDS_curated/sub-NDARLB671TL...
# NDARLY872ZXA    data/Projects/HBN/BIDS_curated/sub-NDARLY872ZX...
# NDARMD666RYJ    data/Projects/HBN/BIDS_curated/sub-NDARMD666RY...
# NDARMH249AWF    data/Projects/HBN/BIDS_curated/sub-NDARMH249AW...
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARNA421FL7    data/Projects/HBN/BIDS_curated/sub-NDARNA421FL...
# NDARNN042YCH    data/Projects/HBN/BIDS_curated/sub-NDARNN042YC...
# NDARPY302MV9    data/Projects/HBN/BIDS_curated/sub-NDARPY302MV...
# NDARRB561VCP    data/Projects/HBN/BIDS_curated/sub-NDARRB561VC...
# NDARRC016UZE    data/Projects/HBN/BIDS_curated/sub-NDARRC016UZ...
# NDARRK038CBD    data/Projects/HBN/BIDS_curated/sub-NDARRK038CB...
# NDARRU499DP2    data/Projects/HBN/BIDS_curated/sub-NDARRU499DP...
# NDARTC795CR3    data/Projects/HBN/BIDS_curated/sub-NDARTC795CR...
# NDARTR464DCR    data/Projects/HBN/BIDS_curated/sub-NDARTR464DC...
# NDARUP132ADW    data/Projects/HBN/BIDS_curated/sub-NDARUP132AD...
# NDARUP441BKK    data/Projects/HBN/BIDS_curated/sub-NDARUP441BK...
# NDARUT651WFC    data/Projects/HBN/BIDS_curated/sub-NDARUT651WF...
# NDARVF786FUU    data/Projects/HBN/BIDS_curated/sub-NDARVF786FU...
# NDARVP285RXV    data/Projects/HBN/BIDS_curated/sub-NDARVP285RX...
# NDARWE130JMG    data/Projects/HBN/BIDS_curated/sub-NDARWE130JM...
# NDARWK051GG4    data/Projects/HBN/BIDS_curated/sub-NDARWK051GG...
# NDARXE854EDK    data/Projects/HBN/BIDS_curated/sub-NDARXE854ED...
# NDARXL801JVG    data/Projects/HBN/BIDS_curated/sub-NDARXL801JV...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYE576WR6    data/Projects/HBN/BIDS_curated/sub-NDARYE576WR...
# NDARYF272EDC    data/Projects/HBN/BIDS_curated/sub-NDARYF272ED...
# NDARYL090TGH    data/Projects/HBN/BIDS_curated/sub-NDARYL090TG...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
# NDARYZ906UHJ    data/Projects/HBN/BIDS_curated/sub-NDARYZ906UH...
#
#                                                  curated_dwi_bvec  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/BIDS_curated/sub-NDARAA504CR...
# NDARAB756JDJ    data/Projects/HBN/BIDS_curated/sub-NDARAB756JD...
# NDARAH976BND    data/Projects/HBN/BIDS_curated/sub-NDARAH976BN...
# NDARAJ977PRJ    data/Projects/HBN/BIDS_curated/sub-NDARAJ977PR...
# NDARBM490LK7    data/Projects/HBN/BIDS_curated/sub-NDARBM490LK...
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDARBR128UFP    data/Projects/HBN/BIDS_curated/sub-NDARBR128UF...
# NDAREC078VFT    data/Projects/HBN/BIDS_curated/sub-NDAREC078VF...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFE372VHL    data/Projects/HBN/BIDS_curated/sub-NDARFE372VH...
# NDARFG568PXZ    data/Projects/HBN/BIDS_curated/sub-NDARFG568PX...
# NDARFV780ABD    data/Projects/HBN/BIDS_curated/sub-NDARFV780AB...
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH425GB9    data/Projects/HBN/BIDS_curated/sub-NDARGH425GB...
# NDARGH790CEF    data/Projects/HBN/BIDS_curated/sub-NDARGH790CE...
# NDARGK253TTG    data/Projects/HBN/BIDS_curated/sub-NDARGK253TT...
# NDARGX443CEU    data/Projects/HBN/BIDS_curated/sub-NDARGX443CE...
# NDARHN078CDT    data/Projects/HBN/BIDS_curated/sub-NDARHN078CD...
# NDARHN482HPM    data/Projects/HBN/BIDS_curated/sub-NDARHN482HP...
# NDARHP395DGY    data/Projects/HBN/BIDS_curated/sub-NDARHP395DG...
# NDARHV358ZCU    data/Projects/HBN/BIDS_curated/sub-NDARHV358ZC...
# NDARJJ173BRX    data/Projects/HBN/BIDS_curated/sub-NDARJJ173BR...
# NDARJZ167VEZ    data/Projects/HBN/BIDS_curated/sub-NDARJZ167VE...
# NDARKC993YWF    data/Projects/HBN/BIDS_curated/sub-NDARKC993YW...
# NDARKN509RP9    data/Projects/HBN/BIDS_curated/sub-NDARKN509RP...
# NDARLB671TLU    data/Projects/HBN/BIDS_curated/sub-NDARLB671TL...
# NDARLY872ZXA    data/Projects/HBN/BIDS_curated/sub-NDARLY872ZX...
# NDARMD666RYJ    data/Projects/HBN/BIDS_curated/sub-NDARMD666RY...
# NDARMH249AWF    data/Projects/HBN/BIDS_curated/sub-NDARMH249AW...
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARNA421FL7    data/Projects/HBN/BIDS_curated/sub-NDARNA421FL...
# NDARNN042YCH    data/Projects/HBN/BIDS_curated/sub-NDARNN042YC...
# NDARPY302MV9    data/Projects/HBN/BIDS_curated/sub-NDARPY302MV...
# NDARRB561VCP    data/Projects/HBN/BIDS_curated/sub-NDARRB561VC...
# NDARRC016UZE    data/Projects/HBN/BIDS_curated/sub-NDARRC016UZ...
# NDARRK038CBD    data/Projects/HBN/BIDS_curated/sub-NDARRK038CB...
# NDARRU499DP2    data/Projects/HBN/BIDS_curated/sub-NDARRU499DP...
# NDARTC795CR3    data/Projects/HBN/BIDS_curated/sub-NDARTC795CR...
# NDARTR464DCR    data/Projects/HBN/BIDS_curated/sub-NDARTR464DC...
# NDARUP132ADW    data/Projects/HBN/BIDS_curated/sub-NDARUP132AD...
# NDARUP441BKK    data/Projects/HBN/BIDS_curated/sub-NDARUP441BK...
# NDARUT651WFC    data/Projects/HBN/BIDS_curated/sub-NDARUT651WF...
# NDARVF786FUU    data/Projects/HBN/BIDS_curated/sub-NDARVF786FU...
# NDARVP285RXV    data/Projects/HBN/BIDS_curated/sub-NDARVP285RX...
# NDARWE130JMG    data/Projects/HBN/BIDS_curated/sub-NDARWE130JM...
# NDARWK051GG4    data/Projects/HBN/BIDS_curated/sub-NDARWK051GG...
# NDARXE854EDK    data/Projects/HBN/BIDS_curated/sub-NDARXE854ED...
# NDARXL801JVG    data/Projects/HBN/BIDS_curated/sub-NDARXL801JV...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYE576WR6    data/Projects/HBN/BIDS_curated/sub-NDARYE576WR...
# NDARYF272EDC    data/Projects/HBN/BIDS_curated/sub-NDARYF272ED...
# NDARYL090TGH    data/Projects/HBN/BIDS_curated/sub-NDARYL090TG...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
# NDARYZ906UHJ    data/Projects/HBN/BIDS_curated/sub-NDARYZ906UH...
#
#                                                 curated_t1w_nifti  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/BIDS_curated/sub-NDARAA504CR...
# NDARAB756JDJ    data/Projects/HBN/BIDS_curated/sub-NDARAB756JD...
# NDARAH976BND    data/Projects/HBN/BIDS_curated/sub-NDARAH976BN...
# NDARAJ977PRJ    data/Projects/HBN/BIDS_curated/sub-NDARAJ977PR...
# NDARBM490LK7    data/Projects/HBN/BIDS_curated/sub-NDARBM490LK...
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDARBR128UFP    data/Projects/HBN/BIDS_curated/sub-NDARBR128UF...
# NDAREC078VFT    data/Projects/HBN/BIDS_curated/sub-NDAREC078VF...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFE372VHL    data/Projects/HBN/BIDS_curated/sub-NDARFE372VH...
# NDARFG568PXZ    data/Projects/HBN/BIDS_curated/sub-NDARFG568PX...
# NDARFV780ABD    data/Projects/HBN/BIDS_curated/sub-NDARFV780AB...
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH425GB9    data/Projects/HBN/BIDS_curated/sub-NDARGH425GB...
# NDARGH790CEF    data/Projects/HBN/BIDS_curated/sub-NDARGH790CE...
# NDARGK253TTG    data/Projects/HBN/BIDS_curated/sub-NDARGK253TT...
# NDARGX443CEU    data/Projects/HBN/BIDS_curated/sub-NDARGX443CE...
# NDARHN078CDT    data/Projects/HBN/BIDS_curated/sub-NDARHN078CD...
# NDARHN482HPM    data/Projects/HBN/BIDS_curated/sub-NDARHN482HP...
# NDARHP395DGY    data/Projects/HBN/BIDS_curated/sub-NDARHP395DG...
# NDARHV358ZCU    data/Projects/HBN/BIDS_curated/sub-NDARHV358ZC...
# NDARJJ173BRX    data/Projects/HBN/BIDS_curated/sub-NDARJJ173BR...
# NDARJZ167VEZ    data/Projects/HBN/BIDS_curated/sub-NDARJZ167VE...
# NDARKC993YWF    data/Projects/HBN/BIDS_curated/sub-NDARKC993YW...
# NDARKN509RP9    data/Projects/HBN/BIDS_curated/sub-NDARKN509RP...
# NDARLB671TLU    data/Projects/HBN/BIDS_curated/sub-NDARLB671TL...
# NDARLY872ZXA    data/Projects/HBN/BIDS_curated/sub-NDARLY872ZX...
# NDARMD666RYJ    data/Projects/HBN/BIDS_curated/sub-NDARMD666RY...
# NDARMH249AWF    data/Projects/HBN/BIDS_curated/sub-NDARMH249AW...
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6    data/Projects/HBN/BIDS_curated/sub-NDARMU589LP...
# NDARNA421FL7    data/Projects/HBN/BIDS_curated/sub-NDARNA421FL...
# NDARNN042YCH    data/Projects/HBN/BIDS_curated/sub-NDARNN042YC...
# NDARPY302MV9    data/Projects/HBN/BIDS_curated/sub-NDARPY302MV...
# NDARRB561VCP    data/Projects/HBN/BIDS_curated/sub-NDARRB561VC...
# NDARRC016UZE    data/Projects/HBN/BIDS_curated/sub-NDARRC016UZ...
# NDARRK038CBD    data/Projects/HBN/BIDS_curated/sub-NDARRK038CB...
# NDARRU499DP2    data/Projects/HBN/BIDS_curated/sub-NDARRU499DP...
# NDARTC795CR3    data/Projects/HBN/BIDS_curated/sub-NDARTC795CR...
# NDARTR464DCR    data/Projects/HBN/BIDS_curated/sub-NDARTR464DC...
# NDARUP132ADW    data/Projects/HBN/BIDS_curated/sub-NDARUP132AD...
# NDARUP441BKK    data/Projects/HBN/BIDS_curated/sub-NDARUP441BK...
# NDARUT651WFC    data/Projects/HBN/BIDS_curated/sub-NDARUT651WF...
# NDARVF786FUU    data/Projects/HBN/BIDS_curated/sub-NDARVF786FU...
# NDARVP285RXV    data/Projects/HBN/BIDS_curated/sub-NDARVP285RX...
# NDARWE130JMG    data/Projects/HBN/BIDS_curated/sub-NDARWE130JM...
# NDARWK051GG4    data/Projects/HBN/BIDS_curated/sub-NDARWK051GG...
# NDARXE854EDK    data/Projects/HBN/BIDS_curated/sub-NDARXE854ED...
# NDARXL801JVG    data/Projects/HBN/BIDS_curated/sub-NDARXL801JV...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYE576WR6    data/Projects/HBN/BIDS_curated/sub-NDARYE576WR...
# NDARYF272EDC    data/Projects/HBN/BIDS_curated/sub-NDARYF272ED...
# NDARYL090TGH    data/Projects/HBN/BIDS_curated/sub-NDARYL090TG...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
# NDARYZ906UHJ    data/Projects/HBN/BIDS_curated/sub-NDARYZ906UH...
#
#                                                  curated_t1w_json  \
# participant_id
# NDARAA504CRN    data/Projects/HBN/BIDS_curated/sub-NDARAA504CR...
# NDARAB756JDJ    data/Projects/HBN/BIDS_curated/sub-NDARAB756JD...
# NDARAH976BND    data/Projects/HBN/BIDS_curated/sub-NDARAH976BN...
# NDARAJ977PRJ    data/Projects/HBN/BIDS_curated/sub-NDARAJ977PR...
# NDARBM490LK7    data/Projects/HBN/BIDS_curated/sub-NDARBM490LK...
# NDARBN365EV3                                                  NaN
# NDARBR128UFP    data/Projects/HBN/BIDS_curated/sub-NDARBR128UF...
# NDAREC078VFT    data/Projects/HBN/BIDS_curated/sub-NDAREC078VF...
# NDAREJ327AH7                                                  NaN
# NDARFE372VHL    data/Projects/HBN/BIDS_curated/sub-NDARFE372VH...
# NDARFG568PXZ    data/Projects/HBN/BIDS_curated/sub-NDARFG568PX...
# NDARFV780ABD                                                  NaN
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH425GB9    data/Projects/HBN/BIDS_curated/sub-NDARGH425GB...
# NDARGH790CEF                                                  NaN
# NDARGK253TTG    data/Projects/HBN/BIDS_curated/sub-NDARGK253TT...
# NDARGX443CEU                                                  NaN
# NDARHN078CDT    data/Projects/HBN/BIDS_curated/sub-NDARHN078CD...
# NDARHN482HPM    data/Projects/HBN/BIDS_curated/sub-NDARHN482HP...
# NDARHP395DGY    data/Projects/HBN/BIDS_curated/sub-NDARHP395DG...
# NDARHV358ZCU    data/Projects/HBN/BIDS_curated/sub-NDARHV358ZC...
# NDARJJ173BRX    data/Projects/HBN/BIDS_curated/sub-NDARJJ173BR...
# NDARJZ167VEZ    data/Projects/HBN/BIDS_curated/sub-NDARJZ167VE...
# NDARKC993YWF    data/Projects/HBN/BIDS_curated/sub-NDARKC993YW...
# NDARKN509RP9                                                  NaN
# NDARLB671TLU    data/Projects/HBN/BIDS_curated/sub-NDARLB671TL...
# NDARLY872ZXA    data/Projects/HBN/BIDS_curated/sub-NDARLY872ZX...
# NDARMD666RYJ    data/Projects/HBN/BIDS_curated/sub-NDARMD666RY...
# NDARMH249AWF                                                  NaN
# NDARMT461DNB                                                  NaN
# NDARMU589LP6    data/Projects/HBN/BIDS_curated/sub-NDARMU589LP...
# NDARNA421FL7    data/Projects/HBN/BIDS_curated/sub-NDARNA421FL...
# NDARNN042YCH    data/Projects/HBN/BIDS_curated/sub-NDARNN042YC...
# NDARPY302MV9    data/Projects/HBN/BIDS_curated/sub-NDARPY302MV...
# NDARRB561VCP    data/Projects/HBN/BIDS_curated/sub-NDARRB561VC...
# NDARRC016UZE                                                  NaN
# NDARRK038CBD    data/Projects/HBN/BIDS_curated/sub-NDARRK038CB...
# NDARRU499DP2    data/Projects/HBN/BIDS_curated/sub-NDARRU499DP...
# NDARTC795CR3    data/Projects/HBN/BIDS_curated/sub-NDARTC795CR...
# NDARTR464DCR    data/Projects/HBN/BIDS_curated/sub-NDARTR464DC...
# NDARUP132ADW    data/Projects/HBN/BIDS_curated/sub-NDARUP132AD...
# NDARUP441BKK    data/Projects/HBN/BIDS_curated/sub-NDARUP441BK...
# NDARUT651WFC    data/Projects/HBN/BIDS_curated/sub-NDARUT651WF...
# NDARVF786FUU    data/Projects/HBN/BIDS_curated/sub-NDARVF786FU...
# NDARVP285RXV    data/Projects/HBN/BIDS_curated/sub-NDARVP285RX...
# NDARWE130JMG    data/Projects/HBN/BIDS_curated/sub-NDARWE130JM...
# NDARWK051GG4    data/Projects/HBN/BIDS_curated/sub-NDARWK051GG...
# NDARXE854EDK    data/Projects/HBN/BIDS_curated/sub-NDARXE854ED...
# NDARXL801JVG    data/Projects/HBN/BIDS_curated/sub-NDARXL801JV...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYE576WR6    data/Projects/HBN/BIDS_curated/sub-NDARYE576WR...
# NDARYF272EDC    data/Projects/HBN/BIDS_curated/sub-NDARYF272ED...
# NDARYL090TGH    data/Projects/HBN/BIDS_curated/sub-NDARYL090TG...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
# NDARYZ906UHJ    data/Projects/HBN/BIDS_curated/sub-NDARYZ906UH...
#
#                 qsiprep_success  in_bids_curated
# participant_id
# NDARAA504CRN              False             True
# NDARAB756JDJ              False             True
# NDARAH976BND              False             True
# NDARAJ977PRJ              False             True
# NDARBM490LK7              False             True
# NDARBN365EV3              False             True
# NDARBR128UFP              False             True
# NDAREC078VFT              False             True
# NDAREJ327AH7              False             True
# NDARFE372VHL              False             True
# NDARFG568PXZ              False             True
# NDARFV780ABD              False             True
# NDARGF367KVL              False             True
# NDARGH425GB9              False             True
# NDARGH790CEF              False             True
# NDARGK253TTG              False             True
# NDARGX443CEU              False             True
# NDARHN078CDT              False             True
# NDARHN482HPM              False             True
# NDARHP395DGY              False             True
# NDARHV358ZCU              False             True
# NDARJJ173BRX              False             True
# NDARJZ167VEZ              False             True
# NDARKC993YWF              False             True
# NDARKN509RP9              False             True
# NDARLB671TLU              False             True
# NDARLY872ZXA              False             True
# NDARMD666RYJ              False             True
# NDARMH249AWF              False             True
# NDARMT461DNB              False             True
# NDARMU589LP6              False             True
# NDARNA421FL7              False             True
# NDARNN042YCH              False             True
# NDARPY302MV9              False             True
# NDARRB561VCP              False             True
# NDARRC016UZE              False             True
# NDARRK038CBD              False             True
# NDARRU499DP2              False             True
# NDARTC795CR3              False             True
# NDARTR464DCR              False             True
# NDARUP132ADW              False             True
# NDARUP441BKK              False             True
# NDARUT651WFC              False             True
# NDARVF786FUU              False             True
# NDARVP285RXV              False             True
# NDARWE130JMG              False             True
# NDARWK051GG4              False             True
# NDARXE854EDK              False             True
# NDARXL801JVG              False             True
# NDARXV294YRJ              False             True
# NDARYE576WR6              False             True
# NDARYF272EDC              False             True
# NDARYL090TGH              False             True
# NDARYX806FL1              False             True
# NDARYZ906UHJ              False             True

# %% [markdown]
# We see that some of these subjects are missing required curated files, even though those files are available in the raw dataset. Other failure modes are more mysterious and will require looking at the QSIprep logs. Let's find the ones with missing curated files.

# %%
len(no_qsiprep[no_qsiprep.isna().any(axis="columns")])
# Out:
# 13

# %%
df_hbn_curated = df_hbn[df_hbn["in_bids_curated"] == True]
df_curation_mismatch = df_hbn_curated[df_hbn_curated.isna().any(axis="columns")]
print(len(df_curation_mismatch))
# Out:
# 725

# %%
np.savetxt(
    "curation_file_mismatch_subs.txt",
    np.array(df_curation_mismatch.index),
    fmt="%s"
)

# %%
df_curation_mismatch[df_curation_mismatch["qsiprep_success"] == False]
# Out:
#                  raw_site                                      raw_dwi_nifti  \
# participant_id
# NDARBN365EV3    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDAREJ327AH7    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFV780ABD      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH790CEF      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGX443CEU      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARKN509RP9      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARMH249AWF      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARRC016UZE      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARXV294YRJ    Site-CBIC  data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYX806FL1      Site-RU  data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
#
#                                                      raw_dwi_json  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
#
#                                                      raw_dwi_bval  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
#
#                                                      raw_dwi_bvec  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
#
#                                                     raw_t1w_nifti  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
#
#                                                      raw_t1w_json  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/MRI/Site-CBIC/sub-NDARBN365E...
# NDAREJ327AH7    data/Projects/HBN/MRI/Site-CBIC/sub-NDAREJ327A...
# NDARFV780ABD    data/Projects/HBN/MRI/Site-RU/sub-NDARFV780ABD...
# NDARGF367KVL    data/Projects/HBN/MRI/Site-RU/sub-NDARGF367KVL...
# NDARGH790CEF    data/Projects/HBN/MRI/Site-RU/sub-NDARGH790CEF...
# NDARGX443CEU    data/Projects/HBN/MRI/Site-RU/sub-NDARGX443CEU...
# NDARKN509RP9    data/Projects/HBN/MRI/Site-RU/sub-NDARKN509RP9...
# NDARMH249AWF    data/Projects/HBN/MRI/Site-RU/sub-NDARMH249AWF...
# NDARMT461DNB    data/Projects/HBN/MRI/Site-CBIC/sub-NDARMT461D...
# NDARMU589LP6    data/Projects/HBN/MRI/Site-RU/sub-NDARMU589LP6...
# NDARRC016UZE    data/Projects/HBN/MRI/Site-RU/sub-NDARRC016UZE...
# NDARXV294YRJ    data/Projects/HBN/MRI/Site-CBIC/sub-NDARXV294Y...
# NDARYX806FL1    data/Projects/HBN/MRI/Site-RU/sub-NDARYX806FL1...
#
#                curated_site  \
# participant_id
# NDARBN365EV3      Site-CBIC
# NDAREJ327AH7      Site-CBIC
# NDARFV780ABD        Site-RU
# NDARGF367KVL        Site-RU
# NDARGH790CEF        Site-RU
# NDARGX443CEU        Site-RU
# NDARKN509RP9        Site-RU
# NDARMH249AWF        Site-RU
# NDARMT461DNB      Site-CBIC
# NDARMU589LP6        Site-RU
# NDARRC016UZE        Site-RU
# NDARXV294YRJ      Site-CBIC
# NDARYX806FL1        Site-RU
#
#                                                 curated_dwi_nifti  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFV780ABD                                                  NaN
# NDARGF367KVL                                                  NaN
# NDARGH790CEF                                                  NaN
# NDARGX443CEU                                                  NaN
# NDARKN509RP9                                                  NaN
# NDARMH249AWF                                                  NaN
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARRC016UZE                                                  NaN
# NDARXV294YRJ                                                  NaN
# NDARYX806FL1                                                  NaN
#
#                                                  curated_dwi_json  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFV780ABD                                                  NaN
# NDARGF367KVL                                                  NaN
# NDARGH790CEF                                                  NaN
# NDARGX443CEU                                                  NaN
# NDARKN509RP9                                                  NaN
# NDARMH249AWF                                                  NaN
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARRC016UZE                                                  NaN
# NDARXV294YRJ                                                  NaN
# NDARYX806FL1                                                  NaN
#
#                                                  curated_dwi_bval  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFV780ABD    data/Projects/HBN/BIDS_curated/sub-NDARFV780AB...
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH790CEF    data/Projects/HBN/BIDS_curated/sub-NDARGH790CE...
# NDARGX443CEU    data/Projects/HBN/BIDS_curated/sub-NDARGX443CE...
# NDARKN509RP9    data/Projects/HBN/BIDS_curated/sub-NDARKN509RP...
# NDARMH249AWF    data/Projects/HBN/BIDS_curated/sub-NDARMH249AW...
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARRC016UZE    data/Projects/HBN/BIDS_curated/sub-NDARRC016UZ...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
#
#                                                  curated_dwi_bvec  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFV780ABD    data/Projects/HBN/BIDS_curated/sub-NDARFV780AB...
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH790CEF    data/Projects/HBN/BIDS_curated/sub-NDARGH790CE...
# NDARGX443CEU    data/Projects/HBN/BIDS_curated/sub-NDARGX443CE...
# NDARKN509RP9    data/Projects/HBN/BIDS_curated/sub-NDARKN509RP...
# NDARMH249AWF    data/Projects/HBN/BIDS_curated/sub-NDARMH249AW...
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6                                                  NaN
# NDARRC016UZE    data/Projects/HBN/BIDS_curated/sub-NDARRC016UZ...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
#
#                                                 curated_t1w_nifti  \
# participant_id
# NDARBN365EV3    data/Projects/HBN/BIDS_curated/sub-NDARBN365EV...
# NDAREJ327AH7    data/Projects/HBN/BIDS_curated/sub-NDAREJ327AH...
# NDARFV780ABD    data/Projects/HBN/BIDS_curated/sub-NDARFV780AB...
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH790CEF    data/Projects/HBN/BIDS_curated/sub-NDARGH790CE...
# NDARGX443CEU    data/Projects/HBN/BIDS_curated/sub-NDARGX443CE...
# NDARKN509RP9    data/Projects/HBN/BIDS_curated/sub-NDARKN509RP...
# NDARMH249AWF    data/Projects/HBN/BIDS_curated/sub-NDARMH249AW...
# NDARMT461DNB    data/Projects/HBN/BIDS_curated/sub-NDARMT461DN...
# NDARMU589LP6    data/Projects/HBN/BIDS_curated/sub-NDARMU589LP...
# NDARRC016UZE    data/Projects/HBN/BIDS_curated/sub-NDARRC016UZ...
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
#
#                                                  curated_t1w_json  \
# participant_id
# NDARBN365EV3                                                  NaN
# NDAREJ327AH7                                                  NaN
# NDARFV780ABD                                                  NaN
# NDARGF367KVL    data/Projects/HBN/BIDS_curated/sub-NDARGF367KV...
# NDARGH790CEF                                                  NaN
# NDARGX443CEU                                                  NaN
# NDARKN509RP9                                                  NaN
# NDARMH249AWF                                                  NaN
# NDARMT461DNB                                                  NaN
# NDARMU589LP6    data/Projects/HBN/BIDS_curated/sub-NDARMU589LP...
# NDARRC016UZE                                                  NaN
# NDARXV294YRJ    data/Projects/HBN/BIDS_curated/sub-NDARXV294YR...
# NDARYX806FL1    data/Projects/HBN/BIDS_curated/sub-NDARYX806FL...
#
#                 qsiprep_success  in_bids_curated
# participant_id
# NDARBN365EV3              False             True
# NDAREJ327AH7              False             True
# NDARFV780ABD              False             True
# NDARGF367KVL              False             True
# NDARGH790CEF              False             True
# NDARGX443CEU              False             True
# NDARKN509RP9              False             True
# NDARMH249AWF              False             True
# NDARMT461DNB              False             True
# NDARMU589LP6              False             True
# NDARRC016UZE              False             True
# NDARXV294YRJ              False             True
# NDARYX806FL1              False             True
